# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/Users/kbircan/projects/winemag/data/winemag-data_first150k.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
# Unnamed: 0     150930 non-null int64
# country        150925 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0 country                                        description  \
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#             designation  points  price            province           region_1  \
# 150925              NaN      91   20.0      Southern Italy  Fiano di Avellino
# 150926   Cuvée Prestige      91   27.0           Champagne          Champagne
# 150927    Terre di Dora      91   20.0      Southern Italy  Fiano di Avellino
# 150928  Grand Brut Rosé      90   52.0           Champagne          Champagne
# 150929              NaN      90   15.0  Northeastern Italy         Alto Adige
#
# ...

# %%
df.points
# Out:
# 0         96
# 1         96
# 2         96
# 3         96
# 4         95
# 5         95
# 6         95
# 7         95
# 8         95
# 9         95
# 10        95
# 11        95
# 12        95
# 13        95
# 14        95
# 15        95
# 16        95
# 17        95
# 18        95
# 19        95
# 20        95
# 21        95
# 22        95
# 23        95
# 24        95
# 25        94
# 26        94
# 27        94
# 28        94
# 29        94
#           ..
# 150900    81
# 150901    81
# 150902    81
# 150903    81
# 150904    81
# 150905    80
# 150906    93
# 150907    92
# 150908    90
# 150909    89
# 150910    89
# 150911    87
# 150912    87
# 150913    94
# 150914    94
# 150915    93
# 150916    93
# 150917    92
# 150918    92
# 150919    91
# 150920    91
# 150921    91
# 150922    91
# 150923    91
# 150924    91
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 150930, dtype: int64

# %%
df[df.country.isnull()]
# Out:
#         Unnamed: 0 country                                        description  \
# 1133          1133     NaN  Delicate white flowers and a spin of lemon pee...
# 1440          1440     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226        68226     NaN  From first sniff to last, the nose never makes...
# 113016      113016     NaN  From first sniff to last, the nose never makes...
# 135696      135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# ...

# %%
df[df.winery == "Chilcas"]
# Out:
#         Unnamed: 0 country                                        description  \
# 19598        19598   Chile  Neutral up front except for green apple and mi...
# 19773        19773   Chile  Dark up front, with aromas of charcoal and cru...
# 20267        20267   Chile  Crisp apple aromas are light and minerally. Fe...
# 20517        20517   Chile  Full in style, with sweet aromas of black frui...
# 30258        30258   Chile  Jammy blackberry and plum aromas come with hin...
# 30582        30582   Chile  Largely neutral aromas touch on melon, peach a...
# 30588        30588   Chile  Aromas of bell pepper and jalapeño come with d...
# 31786        31786   Chile  Dusty raspberry and plum aromas are spicy, dry...
# 35018        35018   Chile  Neutral up front except for green apple and mi...
# 35943        35943   Chile  Dark up front, with aromas of charcoal and cru...
# 38297        38297   Chile  Dry apple aromas are about as much as the nose...
# ...

# %%
df[df.winery == "Tsililis"]
# Out:
#         Unnamed: 0 country                                        description  \
# 1133          1133     NaN  Delicate white flowers and a spin of lemon pee...
# 67148        67148  Greece  This classy Cabernet starts with a big nose of...
# 114308      114308  Greece  This classy Cabernet starts with a big nose of...
# 137258      137258  Greece  This classy Cabernet starts with a big nose of...
#
#        designation  points  price province region_1 region_2  \
# 1133     Askitikos      90   17.0      NaN      NaN      NaN
# 67148    Askitikós      87   18.0   Greece      NaN      NaN
# 114308   Askitikós      87   18.0   Greece      NaN      NaN
# 137258   Askitikós      87   18.0   Greece      NaN      NaN
#
#                    variety    winery
# 1133             Assyrtiko  Tsililis
# 67148   Cabernet Sauvignon  Tsililis
# 114308  Cabernet Sauvignon  Tsililis
# 137258  Cabernet Sauvignon  Tsililis

# %%
df.loc[(df.winery == "Tsililis") & (df.country.isnull()),"country"] = "Greece"

# %%
df.loc[(df.winery == "Tsililis") & (df.country.isnull()),:]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country, description, designation, points, price, province, region_1, region_2, variety, winery]
# Index: []

# %%
df[df.country.isnull()]
# Out:
#         Unnamed: 0 country                                        description  \
# 1440          1440     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226        68226     NaN  From first sniff to last, the nose never makes...
# 113016      113016     NaN  From first sniff to last, the nose never makes...
# 135696      135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
df.loc[(df.winery == "Büyülübağ") & (df.country.isnull()),"country"] = "Turkey"

# %%
df[df.country.isnull()]
# Out:
#         Unnamed: 0 country                                        description  \
# 68226        68226     NaN  From first sniff to last, the nose never makes...
# 113016      113016     NaN  From first sniff to last, the nose never makes...
# 135696      135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#          winery
# 68226   Chilcas
# 113016  Chilcas
# 135696  Chilcas

# %%
df.loc[(df.winery == "Chilcas") & (df.country.isnull()),"country"] = "Chile"

# %%
df[df.country.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country, description, designation, points, price, province, region_1, region_2, variety, winery]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
# Unnamed: 0     150930 non-null int64
# country        150930 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
del df['winery']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
# Unnamed: 0     150930 non-null int64
# country        150930 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 11.5+ MB

# %%
df.loc[df.designation.isnull(), "designation"] = "Other"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
# Unnamed: 0     150930 non-null int64
# country        150930 non-null object
# description    150930 non-null object
# designation    150930 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 11.5+ MB

# %%
df.loc[df.price.isnull(), "price"] = df.price.mean()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
# Unnamed: 0     150930 non-null int64
# country        150930 non-null object
# description    150930 non-null object
# designation    150930 non-null object
# points         150930 non-null int64
# price          150930 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 11.5+ MB

# %%
df.loc[df.region_1.isnull(), "region_1"] = "Other"

# %%
df.loc[df.region_2.isnull(), "region_2"] = "Other"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
# Unnamed: 0     150930 non-null int64
# country        150930 non-null object
# description    150930 non-null object
# designation    150930 non-null object
# points         150930 non-null int64
# price          150930 non-null float64
# province       150925 non-null object
# region_1       150930 non-null object
# region_2       150930 non-null object
# variety        150930 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 11.5+ MB

# %%
del df["description"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 9 columns):
# Unnamed: 0     150930 non-null int64
# country        150930 non-null object
# designation    150930 non-null object
# points         150930 non-null int64
# price          150930 non-null float64
# province       150925 non-null object
# region_1       150930 non-null object
# region_2       150930 non-null object
# variety        150930 non-null object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 10.4+ MB

# %%
del df["designation"]
del df["province"]
del df["region_1"]
del df["region_2"]
del df["variety"]

df = pd.get_dummies(df, columns = ["country"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 51 columns):
# Unnamed: 0                        150930 non-null int64
# points                            150930 non-null int64
# price                             150930 non-null float64
# country_Albania                   150930 non-null uint8
# country_Argentina                 150930 non-null uint8
# country_Australia                 150930 non-null uint8
# country_Austria                   150930 non-null uint8
# country_Bosnia and Herzegovina    150930 non-null uint8
# country_Brazil                    150930 non-null uint8
# country_Bulgaria                  150930 non-null uint8
# country_Canada                    150930 non-null uint8
# country_Chile                     150930 non-null uint8
# country_China                     150930 non-null uint8
# country_Croatia                   150930 non-null uint8
# country_Cyprus                    150930 non-null uint8
# ...

# %%
df.to_csv("/Users/kbircan/projects/winemag/data/winemag-data_first150k_processed.csv")
